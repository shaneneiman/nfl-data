# %%
import pandas as pd
import numpy as np
from utility import pval_pearson_coef, print_column_names, print_shape, check_null_columns

# %%
plays_df = pd.read_csv("datafiles/plays.csv")
week1_df = pd.read_csv("datafiles/week1.csv")

print_shape([plays_df, week1_df])
# Out:
# (19239, 27)
# (986022, 19)

# %%
df = week1_df.replace(np.nan, 0)
mi = df[["gameId", "time", "x", "y", "position", "displayName"]].set_index(["gameId", "time", "position"])
mi.head(20)
# Out:
#                                                   x      y      displayName
# gameId     time                     position
# 2018090600 2018-09-07T01:07:14.599Z QB        91.73  26.67        Matt Ryan
#                                     SS        88.89  36.47  Malcolm Jenkins
#                                     WR        91.35  44.16      Julio Jones
#                                     FS        86.31  22.01     Corey Graham
#                                     WR        90.78  36.15     Mohamed Sanu
#                                     FS        73.64  28.70    Rodney McLeod
#                                     RB        98.25  26.63  Devonta Freeman
#                                     MLB       86.48  31.12     Jordan Hicks
#                                     CB        82.67  20.53     Ronald Darby
#                                     CB        84.00  43.49      Jalen Mills
#                                     TE        91.29  21.83    Austin Hooper
#                                     LB        85.63  26.59       Nate Gerry
#                                     FB        95.13  26.71      Ricky Ortiz
#                                     0         90.11  26.85         Football
#            2018-09-07T01:07:14.700Z QB        91.73  26.67        Matt Ryan
#                                     SS        88.89  36.47  Malcolm Jenkins
#                                     WR        91.37  44.17      Julio Jones
#                                     FS        86.32  22.00     Corey Graham
#                                     WR        90.78  36.15     Mohamed Sanu
#                                     FS        73.64  28.70    Rodney McLeod
